# %% [markdown]
# ## Plot Frequency from WAV

# %%
from scipy.fftpack import fft
from scipy.io import wavfile as wav
import matplotlib.pyplot as plt
import numpy as np

# %%
f = "C:/users/ganzk/desktop/notebooks/dev_notebooks/rob/hydrophone/OO_HYVM1__YDH_2017_10_06T00_00_00.wav"

# %%
rate, data = wav.read(f)
fou = fft(data)

# %%
# %matplotlib inline
plt.plot(data, np.abs(fou))
plt.show()
