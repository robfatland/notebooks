# %%
# !pwd
# !ls -al **45.jpg
# Out:
# /home/robfatland/notebooks/dev_notebooks/rob/hydrophone
# -rw-r--r-- 1 robfatland robfatland 123757 Jun  1 20:55 OO_HYVM1__YDH_2017_10_06T00_00_45.jpg
# -rw-r--r-- 1 robfatland robfatland 132565 Jun  1 20:56 OO_HYVM1__YDH_2017_10_06T00_01_45.jpg
# -rw-r--r-- 1 robfatland robfatland 136877 Jun  1 20:57 OO_HYVM1__YDH_2017_10_06T00_02_45.jpg
# -rw-r--r-- 1 robfatland robfatland 142272 Jun  1 20:57 OO_HYVM1__YDH_2017_10_06T00_03_45.jpg
# -rw-r--r-- 1 robfatland robfatland 147160 Jun  1 20:58 OO_HYVM1__YDH_2017_10_06T00_04_45.jpg
# -rw-r--r-- 1 robfatland robfatland 127932 Jun  1 20:59 OO_HYVM1__YDH_2017_10_06T00_05_45.jpg

# %%
import IPython
# IPython.display.Audio("../audio/Hydrophone_example.mp3")
IPython.display.Audio("./OO_HYVM1__YDH_2017_10_06T00_00_00.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# images
# !cp ./../kilroy/kilroy.py .
import kilroy
kilroy.ShowLocal('./OO_HYVM1__YDH_2017_10_06T00_05_45.jpg', 600,500)
# Out:
# <PIL.Image.Image image mode=RGB size=600x500 at 0x7F9B308992E8>
